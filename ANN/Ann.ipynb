# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Churn_Modelling.csv')
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
dataset.shape
# Out:
# (10000, 14)

# %%
### Remove columns that we dont need in Training
X = dataset.iloc[:,3:13]
y = dataset.iloc[:,13]

X.shape,y.shape
# Out:
# ((10000, 10), (10000,))

# %%
X.dtypes
# Out:
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# dtype: object

# %%
### Creating Dummy varaibles

geography = pd.get_dummies(X['Geography'],drop_first=True)
gender = pd.get_dummies(X['Gender'],drop_first=True)

### Concat Dummy columns to X
X = pd.concat([X,geography,gender],axis=1)
X.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Germany  Spain   Male
# 0          1               1        101348.88    False  False  False
# 1          0               1        112542.58    False   True  False
# 2          1               0        113931.57    False  False  False
# 3          0               0         93826.63    False  False  False
# 4          1               1         79084.10    False   True  False

# %%
### Drop Object columns
X = X.drop(['Geography','Gender'],axis=1)
X.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Germany  Spain   Male
# 0               1        101348.88    False  False  False
# 1               1        112542.58    False   True  False
# 2               0        113931.57    False  False  False
# 3               0         93826.63    False  False  False
# 4               1         79084.10    False   True  False

# %%
### Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((8000, 11), (2000, 11), (8000,), (2000,))

# %%
### Feature Scaling

from sklearn.preprocessing import StandardScaler  # make balance between number 0 and 1 treat all number equally
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
X_train
# Out:
# array([[ 0.16958176, -0.46460796,  0.00666099, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-2.30455945,  0.30102557, -1.37744033, ...,  1.75486502,
#         -0.57369368,  0.91601335],
#        [-1.19119591, -0.94312892, -1.031415  , ..., -0.5698444 ,
#         -0.57369368, -1.09168714],
#        ...,
#        [ 0.9015152 , -0.36890377,  0.00666099, ..., -0.5698444 ,
#         -0.57369368,  0.91601335],
#        [-0.62420521, -0.08179119,  1.39076231, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-0.28401079,  0.87525072, -1.37744033, ...,  1.75486502,
#         -0.57369368, -1.09168714]])

# %%
X_train.shape
# Out:
# (8000, 11)

# %%
# Artificial Neural Network --- ANN

### Import Keras libraries and packages

from tensorflow.keras.models import Sequential # taking entire block of neural network ie- forward and backward proporgation
from tensorflow.keras.layers import Dense # with the help of this we are able to create layers - hidden layer,input,output layer
from tensorflow.keras.layers import LeakyReLU,PReLU,ELU # will use inside hidden layer
from tensorflow.keras.layers import Dropout # it drops the dead neurons and reduce the overfitting issue

# %%
# Initializing ANN Architecture --- Sequential
classifier = Sequential()

# %%
# Adding the input layer with the help of dense ..... so we have 11 inputs or columns
classifier.add(Dense(units=11,activation='relu'))

# %%
# Adding the first hidden layer
classifier.add(Dense(units=6,activation='relu'))

# %%
# Adding the Second hidden layer
classifier.add(Dense(units=6,activation='relu'))

# %%
# Adding the output layer
classifier.add(Dense(1,activation='sigmoid')) # since it is binary classification we use sigmoid activation function and 1 neuron

# %%
# Compile ANN ---- Loss Function,Optimizer,Metrics

classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
# After some time accuracy will remain same it iterate in same accuracy
# how to decide number of epocs ? for this we use earlystopping method

# %%
# Earlytopping - when the accuracy is not at all increasing it automatically the training of the model will stop

# %%
import tensorflow as tf
earlystopping =tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0,
)

# %%
# Training our entire neural netwrok
story=classifier.fit(X_train,y_train,validation_split=0.33,epochs=1000,batch_size=10,callbacks=earlystopping)
# Out:
# Epoch 1/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7930 - loss: 0.4117 - val_accuracy: 0.7955 - val_loss: 0.4242
# Epoch 2/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7897 - loss: 0.4049 - val_accuracy: 0.7955 - val_loss: 0.4218
# Epoch 3/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7966 - loss: 0.3962 - val_accuracy: 0.7955 - val_loss: 0.4179
# Epoch 4/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7935 - loss: 0.3916 - val_accuracy: 0.7955 - val_loss: 0.4189
# Epoch 5/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8024 - loss: 0.3909 - val_accuracy: 0.8092 - val_loss: 0.4173
# Epoch 6/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8225 - loss: 0.3968 - val_accuracy: 0.8126 - val_loss: 0.4141
# Epoch 7/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8264 - loss: 0.3820 - val_accuracy: 0.8092 - val_loss: 0.4146
# Epoch 8/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8213 - loss: 0.3982 - val_accuracy: 0.7978 - val_loss: 0.4164
# Epoch 9/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.
1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8756 - loss: 0.3105 - val_accuracy: 0.8531 - val_loss: 0.3669
# Epoch 105/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8761 - loss: 0.3208 - val_accuracy: 0.8523 - val_loss: 0.3652
# Epoch 105: early stopping

# %%
classifier.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 6)              │            42 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             7 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │             2 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             2 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 779 (3.05 KB)
#  Trainable params: 259 (1.01 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 520 (2.04 KB)

# %%
# Predicting Test Result Set
y_pred = classifier.predict(X_test)
y_pred =(y_pred >=0.5)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

print(accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.857
# [[1508   87]
#  [ 199  206]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91      1595
#            1       0.70      0.51      0.59       405
#
#     accuracy                           0.86      2000
#    macro avg       0.79      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000

# %%
    # To see the weights
classifier.get_weights()
# Out:
# [array([[ 4.49264888e-03,  7.43303671e-02, -4.46110606e-01,
#           3.90824415e-02,  4.03778195e-01, -5.07597513e-02,
#           1.48840249e-01, -1.41979292e-01, -9.45959389e-02,
#           2.66692221e-01,  2.54264921e-01],
#         [ 1.38666958e-01, -2.22446591e-01, -9.13194895e-01,
#           2.30335444e-01, -7.00221479e-01,  4.80600819e-02,
#           3.54282081e-01, -8.32203150e-01,  1.62621960e-01,
#          -5.28281331e-01, -9.72388268e-01],
#         [ 5.58505356e-02,  4.89241809e-01,  2.34946072e-01,
#          -5.79540655e-02,  1.74148768e-01,  9.42307059e-03,
#           7.22584546e-01,  6.04525767e-02,  4.11526933e-02,
#          -3.76994684e-02,  1.79944873e-01],
#         [-4.52165276e-01, -6.63716078e-01,  3.61427367e-02,
#           1.50871658e+00, -1.15353334e+00,  3.03154022e-01,
#          -2.77272254e-01, -1.42474517e-01, -8.97737920e-01,
#           8.06548476e-01,  2.88825393e-01],
#         [-1.05153430e+00, -9.76043463e-01,  2.09681451e-01,
#           1.05605766e-01,  7.66399682e-01,  1.56283998e+00,
#          -1.32488906e-01,  1.91402942e-01,  2.40692049e-01,
#          -1.94994003e-01,  2.77649462e-02],
#         [ 9.26490128e-03, -2.76868343e-01,  1.31593198e-01,
#           9.24117416e-02, -5.11406720e-01, -1.77725572e-02,
#          -2.68688530e-01, -2.30046183e-01,  2.30115503e-01,
#           4.31933999e-01,  1.24625467e-01],
#         [-4.57219601e-01,  2.87099063e-01,  1.45738274e-01,
#           1.70462094e-02, -2.28753850e-01, -4.16515648e-01,
#           7.22087443e-01, -4.78560954e-01,  2.47398466e-01,
#          -6.57995269e-02, -2.47721791e-01],
#         [-2.02363893e-01,  3.30320925e-01, -2.08216652e-01,
#           1.32573113e-01, -2.13181358e-02,  7.10103065e-02,
#          -1.75789341e-01, -4.24214453e-02,  2.36561209e-01,
#           4.33468580e-01, -2.84173712e-02],
#         [ 3.58069837e-01, -4.84739840e-02, -2.01150179e-01,
#           3.39218020e-01,  3.03429127e-01, -1.83777697e-02,
#          -3.32881629e-01, -2.80455709e-01,  9.11613107e-01,
#          -5.08348525e-01,  1.47769019e-01],
#         [-3.35625489e-03,  1.15648568e-01, -3.06536436e-01,
#          -4.63188589e-01,  1.08885363e-01,  3.00907856e-03,
#           1.74431235e-01, -2.52556682e-01,  1.23578906e-01,
#           1.61370873e-01, -1.33198142e+00],
#         [-1.68750003e-01,  1.26109570e-01,  1.14113700e+00,
#          -6.03483021e-02,  8.29963028e-01, -9.38360468e-02,
#           1.18619271e-01, -6.54363394e-01, -2.63515353e-01,
#           1.23437285e-01, -6.31933566e-04]], dtype=float32),
#  array([ 0.38268715, -0.14872223,  0.7913576 , -0.4758265 ,  0.4616728 ,
#         -0.48727345,  0.39283836,  0.5428251 , -0.41467565, -0.15917818,
#          0.3179539 ], dtype=float32),
#  array([[-0.09675947, -0.07380097, -0.35703686,  0.4534595 ,  0.38564122,
#           0.6130666 ],
#         [-0.51790285, -0.26157334, -0.07713657,  0.09883387, -0.4675776 ,
#           0.5890718 ],
#         [ 0.8748821 ,  0.2640011 ,  0.1904673 , -0.05719675,  0.05272349,
#           0.20095077],
#         [-0.28794214,  0.6508842 , -0.96353465, -0.24581309, -0.6874686 ,
#           0.7136343 ],
#         [ 0.6158741 , -0.71421874,  0.73812306,  0.41207278,  0.9257091 ,
#          -0.44533494],
#         [-0.0150157 , -0.5479352 , -0.69519544,  0.95689666, -0.75080496,
#          -3.1027625 ],
#         [-0.5137625 ,  0.3774822 ,  0.1778235 ,  0.10155973,  0.49810672,
#          -0.47511244],
#         [-0.06873535,  0.48203003,  0.05190852, -0.5552748 ,  0.01455008,
#           0.09702907],
#         [-0.4662527 , -0.629333  ,  0.4351302 , -0.4810352 ,  0.48585615,
#          -0.45293933],
#         [ 0.4238831 , -0.7117072 ,  0.75048554, -0.3010614 ,  0.23245436,
#           0.16172335],
#         [ 0.88817316,  0.8706834 ,  0.01487285,  0.17426802, -0.3342131 ,
#          -0.11391333]], dtype=float32),
#  array([ 0.45234   ,  0.01853258,  0.13681312,  0.10252658,  0.23240387,
#         -0.03051073], dtype=float32),
#  array([[ 0.51465607, -0.56356007, -0.12887199,  0.33388832,  0.03561511,
#          -0.2567601 ],
#         [-0.44706744,  0.4827589 ,  0.27883732,  0.643592  , -0.65010315,
#          -0.6180422 ],
#         [ 0.25860426,  0.55728966, -0.35877964,  0.5493994 , -0.5556949 ,
#           0.38300166],
#         [-0.96643406, -1.2220557 ,  0.79677105, -0.18207715, -0.18066005,
#           0.78647506],
#         [ 0.48611352,  0.23160057,  0.04473382,  1.095951  , -0.01217355,
#          -0.30452123],
#         [-0.5815758 , -0.05434255,  0.4973476 , -0.1800849 , -0.3163597 ,
#           0.6693831 ]], dtype=float32),
#  array([-0.14964134, -0.30826926,  0.30929962,  0.17955332, -0.06063816,
#          0.00417755], dtype=float32),
#  array([[-0.01689836],
#         [ 1.4217128 ],
#         [-0.54937667],
#         [ 0.33380547],
#         [-0.19504951],
#         [-0.5597328 ]], dtype=float32),
#  array([0.16381417], dtype=float32),
#  array([[5.237805]], dtype=float32),
#  array([-2.731193], dtype=float32),
#  array([[-5.897064]], dtype=float32),
#  array([2.2265775], dtype=float32),
#  array([[6.832798]], dtype=float32),
#  array([-3.664025], dtype=float32)]

# %%
print(model_history.history.keys())
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])
